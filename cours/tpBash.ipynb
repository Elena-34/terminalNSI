# %% [markdown]
# # 1 Afficher le dossier courant.
# ```bash
# $ pwd
# ```
# # 2 Remonter dans le répertoire /home/vscode.
# ```bash
# $ cd ../../../home/vscode  #chemin relatif
# $ cd /home/vscode          #chemin absolu
# ```
# # 3 Créer un dossier miniTP dans ce répertoire.
# ```bash
# $ mkdir ./miniTP
# ```
# # 4 Afficher le contenu de tous les fichiers ou dossiers présents ici.
# ```bash
# $ ls -a
# ```
# # 5 Créer un fichier vide notes.txt.
# ```bash
# $ touch ./notes.txt
# ```
# # 6 Ajouter dans ce fichier la ligne "Linux is powerful".
# ```bash
# $ nano ./notes.txt   #puis on tape le texte a écrire et on sauvegarde.
# $ echo "Salut les zouzous." > ./notes.txt   #redirection qui écrase.
# $ echo "Salut les zouzous." >> ./notes.txt  #redirection qui écrase pas le contenu déjà existant.
# ```
# # 7 Renommer ce fichier "essai.md" sans le déplacer en "tableauDeCommandes.md", et "notes.txt" en "notes_backup.txt"
# ```bash
# $ mv /workspaces/terminalNSI/cours/tableauDeCommandes.txt /workspaces/terminalNSI/cours/tableauDeCommandes.md
# $ mv ./notes.txt ./notes_backup.txt
# ```
# # 8 Copier le fichier dans le dossier "cours" de votre workspace.
# ```bash
# $ cp ./notes_backup.txt /workspaces/terminalNSI/cours/notes_backup.txt
# ```
# # 9 Compter de nombre de mot dans le fichier.
# ```bash
#
# ```
# # 10 Afficher la/les lignes avec le mot "powerful" dans la console.
# ```bash
#
# ```
